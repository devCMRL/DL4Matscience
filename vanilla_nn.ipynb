# %% [markdown]
# Example of implementing a perceptron with tensorflow

# %%
from Tensorflow_Scripts.perceptron_tf import PerceptronTF
import tensorflow as tf #type: ignore
import numpy as np #type: ignore
from sklearn.model_selection import train_test_split #type: ignore

''' Generate dummy data: 10 examples with 5 features each.'''
dummy_data_tf = np.random.random((10, 5))
dummy_targets_tf = np.random.random((10, 1))

X_train, X_test, y_train, y_test = train_test_split(dummy_data_tf, dummy_targets_tf, test_size=0.2, random_state=42)

''' Instantiate the TensorFlow perceptron model., Activation functions: relu, sigmoid, tanh'''
model_tf = PerceptronTF(input_dim=5, output_dim=1, activation='relu')
model_tf.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse')

print("Training the model...")
model_tf.fit(X_train, y_train, epochs=100, verbose=1)
print("Training complete.\n")

loss = model_tf.evaluate(X_test, y_test, verbose=0)
print("Test loss:", loss)

predictions = model_tf(X_test)
print("Predictions on test set:", predictions.numpy())
# Out:
# Training the model...
# Epoch 1/100
# /Users/devcmrl/Desktop/Fall 2024/Professional Projects/DL4Matscience/DeepL/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 0.2024
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1957
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1889
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1827
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1773
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1720
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1678
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1631
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1608
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1606
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1618
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1636
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1652
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1661
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1662
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1655
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1642
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1628
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1613
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1601
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1592
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1588
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1587
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1589
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1591
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1594
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1595
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1594
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1591
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1587
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1582
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1577
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1573
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1569
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1567
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1566
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1566
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1565
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1565
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1564
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1563
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1561
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1558
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1556
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1553
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1551
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1550
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1549
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1548
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1547
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1546
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1545
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1543
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1542
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1540
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1539
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1538
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1536
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1535
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1534
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1533
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1532
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1531
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1530
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1529
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1528
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1527
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1526
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1525
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1524
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1523
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1522
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1521
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1520
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1519
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1518
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1517
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1517
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1516
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1515
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1514
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1513
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1513
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1512
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1511
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1510
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1510
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1509
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1508
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1507
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1507
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1506
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1505
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1505
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1504
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1504
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1503
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1502
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1502
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1501
# Training complete.
#
# Test loss: 0.19654130935668945
# Predictions on test set: [[0.23125798]
#  [0.3049787 ]]

# %% [markdown]
# Example of implementing a perceptron with PyTorch

# %%
from PyTorch_Scripts.perceptron_torch import PerceptronTorch
import torch #type: ignore
import torch.nn as nn #type: ignore
import torch.optim as optim     #type: ignore
import numpy as np   #type: ignore
from sklearn.model_selection import train_test_split    #type: ignore

''' Generate dummy data: 10 examples with 5 features each.'''
dummy_data_torch = np.random.random((10, 5))
dummy_targets_torch = np.random.random((10, 1))

X_train, X_test, y_train, y_test = train_test_split(
    dummy_data_torch, dummy_targets_torch, test_size=0.2, random_state=42
)

''' Convert numpy arrays to torch tensors.'''
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

model_torch = PerceptronTorch(input_dim=5, output_dim=1, activation='relu')

''' Define the loss function and optimizer.'''
criterion = nn.MSELoss()
optimizer = optim.Adam(model_torch.parameters(), lr=0.01)

epochs = 100
print("Training PyTorch model...")
for epoch in range(epochs):
    model_torch.train()  # Set the model to training mode.
    optimizer.zero_grad()  # Reset gradients.
    outputs = model_torch(X_train_tensor)  # Forward pass.
    loss = criterion(outputs, y_train_tensor)  # Compute the loss.
    loss.backward()  # Backward pass.
    optimizer.step()  # Update the weights.
    if (epoch + 1) % 20 == 0:
        print(f"Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}")

print("Training complete.\n")

model_torch.eval()  # Set the model to evaluation mode.
with torch.no_grad():
    test_outputs = model_torch(X_test_tensor)
    test_loss = criterion(test_outputs, y_test_tensor)
print("Test loss:", test_loss.item())
print("Predictions on test set:", test_outputs.numpy())
# Out:
# Training PyTorch model...
# Epoch [20/100], Loss: 0.0595
# Epoch [40/100], Loss: 0.0376
# Epoch [60/100], Loss: 0.0262
# Epoch [80/100], Loss: 0.0180
# Epoch [100/100], Loss: 0.0123
# Training complete.
#
# Test loss: 0.12785546481609344
# Predictions on test set: [[0.6806306 ]
#  [0.31053722]]
