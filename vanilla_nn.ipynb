# %% [markdown]
# Example of implementing a perceptron with tensorflow

# %%
from Tensorflow_Scripts.perceptron_tf import PerceptronTF
import tensorflow as tf #type: ignore
import numpy as np #type: ignore
from sklearn.model_selection import train_test_split #type: ignore
import warnings

warnings.filterwarnings("ignore")

''' Generate dummy data: 10 examples with 5 features each.'''
dummy_data_tf = np.random.random((10, 5))
dummy_targets_tf = np.random.random((10, 1))

X_train, X_test, y_train, y_test = train_test_split(dummy_data_tf, dummy_targets_tf, test_size=0.2, random_state=42)

''' Instantiate the TensorFlow perceptron model., Activation functions: relu, sigmoid, tanh'''
model_tf = PerceptronTF(input_dim=5, output_dim=1, activation='relu')
model_tf.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse')

print("Training the model...")
model_tf.fit(X_train, y_train, epochs=100, verbose=1)
print("Training complete.\n")

loss = model_tf.evaluate(X_test, y_test, verbose=0)
print("Test loss:", loss)

predictions = model_tf(X_test)
print("Predictions on test set:", predictions.numpy())
# Out:
# Training the model...
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.1925
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1827
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1742
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1671
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1612
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1565
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1526
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1494
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1466
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1438
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1409
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1379
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1348
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1316
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1284
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1253
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1223
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1196
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1170
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1147
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1125
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1105
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1086
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1068
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1050
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1032
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1014
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0997
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0980
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0964
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0948
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0934
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0920
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0908
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0896
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0884
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0872
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0861
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0850
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0839
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0829
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0818
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0808
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0798
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0789
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0779
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0770
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0762
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0753
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0744
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0735
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0727
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0718
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0710
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0702
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0694
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0686
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0679
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0671
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0663
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0656
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0649
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0642
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0635
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0628
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0621
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0614
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0608
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0602
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0595
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0589
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0583
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0578
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0572
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0566
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0561
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0555
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0550
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0545
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0540
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0535
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0530
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0526
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0521
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0516
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0512
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0508
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0504
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0500
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0496
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0492
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0488
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0484
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0481
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0477
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0474
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0471
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0467
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0464
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0461
# Training complete.
#
# Test loss: 0.32354387640953064
# Predictions on test set: [[0.564396 ]
#  [0.7072057]]

# %% [markdown]
# Example of implementing a perceptron with PyTorch

# %%
from PyTorch_Scripts.perceptron_torch import PerceptronTorch
import torch #type: ignore
import torch.nn as nn #type: ignore
import torch.optim as optim     #type: ignore
import numpy as np   #type: ignore
from sklearn.model_selection import train_test_split    #type: ignore

''' Generate dummy data: 10 examples with 5 features each.'''
dummy_data_torch = np.random.random((10, 5))
dummy_targets_torch = np.random.random((10, 1))

X_train, X_test, y_train, y_test = train_test_split(
    dummy_data_torch, dummy_targets_torch, test_size=0.2, random_state=42
)

''' Convert numpy arrays to torch tensors.'''
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

model_torch = PerceptronTorch(input_dim=5, output_dim=1, activation='relu')

''' Define the loss function and optimizer.'''
criterion = nn.MSELoss()
optimizer = optim.Adam(model_torch.parameters(), lr=0.01)

epochs = 100
print("Training PyTorch model...")
for epoch in range(epochs):
    model_torch.train()  # Set the model to training mode.
    optimizer.zero_grad()  # Reset gradients.
    outputs = model_torch(X_train_tensor)  # Forward pass.
    loss = criterion(outputs, y_train_tensor)  # Compute the loss.
    loss.backward()  # Backward pass.
    optimizer.step()  # Update the weights.
    if (epoch + 1) % 20 == 0:
        print(f"Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}")

print("Training complete.\n")

model_torch.eval()  # Set the model to evaluation mode.
with torch.no_grad():
    test_outputs = model_torch(X_test_tensor)
    test_loss = criterion(test_outputs, y_test_tensor)
print("Test loss:", test_loss.item())
print("Predictions on test set:", test_outputs.numpy())
# Out:
# Training PyTorch model...
# Epoch [20/100], Loss: 0.0595
# Epoch [40/100], Loss: 0.0376
# Epoch [60/100], Loss: 0.0262
# Epoch [80/100], Loss: 0.0180
# Epoch [100/100], Loss: 0.0123
# Training complete.
#
# Test loss: 0.12785546481609344
# Predictions on test set: [[0.6806306 ]
#  [0.31053722]]
